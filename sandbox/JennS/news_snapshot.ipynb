# %%
import pandas as pd
from newsapi import NewsApiClient

# Import api key
from config import api_key_news

# %% [markdown]
# # Extract News

# %%
# Start session
newsapi = NewsApiClient(api_key=api_key_news)

# %% [markdown]
# ### Get just BTC

# %%
BTC_snapshot = newsapi.get_everything(q='bitcoin OR btc',
                                      from_param='2023-03-15',
                                      to='2023-04-14',
                                      language='en')

# %% [markdown]
# ### Get just DOGE

# %%
doge_snapshot = newsapi.get_everything(q='dogecoin OR doge',
                                      from_param='2023-03-15',
                                      to='2023-04-14',
                                      language='en')

# %% [markdown]
# ### Bank Snapshot

# %%
bank_snapshot = newsapi.get_everything(q='bank',
                                      from_param='2023-03-11',
                                      to='2023-04-09',
                                      language='en')

# %%
bank_snapshot
# Out:
# {'status': 'ok',
#  'totalResults': 72868,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Devindra Hardawar',
#    'title': 'Engadget Podcast: Why did Silicon Valley Bank fail so hard?',
#    'description': 'The downfall of Silicon Valley bank affects the entire technology industry. This week, we chat with Alex Wilhelm, editor in chief at TechCrunch+, about why SVB failed and what it means for the broader ecosystem. Where were the regulations? And why were VCs so…',
#    'url': 'https://www.engadget.com/engadget-podcast-elon-musk-neuralink-human-trials-denied-123014095.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/tdmZDSyzf3jjlI17q4HATQ--~B/Zmk9ZmlsbDtoPTYzMDtweW9mZj0wO3c9MTIwMDthcHBpZD15dGFjaHlvbg--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-05/f43b53b0-909f-11ea-87fd-d8d721459924.cf.jpg',
#    'publishedAt': '2023-03-17T12:30:14Z',
#    'content': 'The downfall of Silicon Valley bank affects the entire technology industry. This week, we chat with Alex Wilhelm, editor in chief at TechCrunch+, about why SVB failed and what it means for the broade… [+1721 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Steve Dent',
#    'title': 'US regulators will protect all deposits at Silicon Valley Bank',
#    'description': 'US regulators have announced that they\'re taking action to "fully" protect all deposits at Silicon Valley Bank (SVB), CNBC has reported. The institution is home to a large number of startups and established companies like Roku and Etsy, which will have full a…',
#    'url': 'https://www.engadget.com/us-regulators-will-protect-all-deposits-at-silicon-valley-bank-045837677.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/GG55.lJRrhAKn81IRfy7Sg--~B/Zmk9ZmlsbDtoPTYzMDtweW9mZj0wO3c9MTIwMDthcHBpZD15dGFjaHlvbg--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2023-03/97ee76a0-c152-11ed-bd79-862a0131fd8d.cf.jpg',
#    'publishedAt': '2023-03-13T04:58:37Z',
#    'content': 'US regulators have announced that they\'re taking action to "fully" protect all deposits at Silicon Valley Bank (SVB), CNBC has reported. The institution is home to a large number of startups and esta… [+2436 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Igor Bonifacic',
#    'title': 'USDC stablecoin breaks dollar peg following Silicon Valley Bank collapse',
#    'description': 'The abrupt collapse of Silicon Valley Bank has affected the value of the world’s fifth-largest cryptocurrency, increasing fears of a possible ripple effect among Web3 companies. On Saturday morning, USD Coin fell to a record low of $0.87 after Circle, the com…',
#    'url': 'https://www.engadget.com/usdc-stablecoin-breaks-dollar-peg-following-silicon-valley-bank-collapse-232052571.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/lISMpIO8taATc20UwEOasQ--~B/Zmk9ZmlsbDtoPTYzMDtweW9mZj0wO3c9MTIwMDthcHBpZD15dGFjaHlvbg--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2023-03/c04f51a0-bf86-11ed-ad7d-a5b0b18e557e.cf.jpg',
#    'publishedAt': '2023-03-11T23:20:52Z',
#    'content': 'The abrupt collapse of Silicon Valley Bank has affected the value of the worlds fifth-largest cryptocurrency, increasing fears of a possible ripple effect among Web3 companies. On Saturday morning, U… [+1636 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Varsha Bansal',
#    'title': 'SVB’s Collapse Is Causing Chaos in India’s Tech Sector',
#    'description': 'The bank was popular among Indian founders who needed US accounts. But many have struggled to get their money out.',
#    'url': 'https://www.wired.com/story/svbs-collapse-is-causing-chaos-in-indias-tech-sector/',
#    'urlToImage': 'https://media.wired.com/photos/640f8d1cfcebf513b041528f/191:100/w_1280,c_limit/down_trend_biz_GettyImages-1017275652.jpg',
#    'publishedAt': '2023-03-13T21:00:00Z',
#    'content': 'In case of India, the number of Indian startups [impacted] is definitely very high compared to other nations, except for US, but the capital would not be as much, says Smriti Tomar, founder and CEO o… [+2819 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Vidhura S. Tennekoon',
#    'title': 'Why Did Silicon Valley Bank and Signature Bank Fail So Fast?',
#    'description': 'Silicon Valley Bank and Signature Bank failed with enormous speed – so quickly that they could be textbook cases of classic bank runs, in which too many depositors withdraw their funds from a bank at the same time. The failures at SVB and Signature were two o…',
#    'url': 'https://gizmodo.com/silicon-valley-bank-signature-bank-fail-so-fast-1850227581',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/133783985c6e54575e80736e7ccdfa32.jpg',
#    'publishedAt': '2023-03-15T13:02:00Z',
#    'content': 'Silicon Valley Bank and Signature Bank failed with enormous speed so quickly that they could be textbook cases of classic bank runs, in which too many depositors withdraw their funds from a bank at t… [+5205 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Joel Khalili',
#    'title': 'Crypto Faces a Banking Crisis. For Some, It’s a Conspiracy',
#    'description': 'The collapse of crypto-friendly Silvergate and Signature Bank has left the industry scrambling to find anyone willing to work with them.',
#    'url': 'https://www.wired.com/story/crypto-banking-crisis/',
#    'urlToImage': 'https://media.wired.com/photos/64126824df4962e1cbeeca67/191:100/w_1280,c_limit/Crpto-Banks-Business.jpg',
#    'publishedAt': '2023-03-16T11:00:00Z',
#    'content': 'A group of Republican senators, led by Bill Hagerty of Tennessee, penned a\xa0letter to the banking regulators on March 9, supporting this interpretation. The statements issued by regulators have caused… [+3757 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Karissa Bell',
#    'title': 'Roku says it could lose 25 percent of its cash after Silicon Valley Bank fails',
#    'description': 'The sudden collapse of Silicon Valley Bank has put more than a quarter of Roku’s cash at risk. The streaming company had nearly $500 million, representing 26 percent of its cash, in Silicon Valley Bank, the company disclosed in an SEC filing\r\n Friday.The futu…',
#    'url': 'https://www.engadget.com/roku-says-it-could-lose-25-percent-of-its-cash-after-silicon-valley-bank-fails-000615481.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/F8jypAH2yIB8cw7nQMSo8Q--~B/Zmk9ZmlsbDtoPTYzMDtweW9mZj0wO3c9MTIwMDthcHBpZD15dGFjaHlvbg--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2023-03/93555ce0-bf99-11ed-b7bd-4e7d6140450c.cf.jpg',
#    'publishedAt': '2023-03-11T00:06:15Z',
#    'content': 'The sudden collapse of Silicon Valley Bank has put more than a quarter of Rokus cash at risk. The streaming company had nearly $500 million, representing 26 percent of its cash, in Silicon Valley Ban… [+2688 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Krystal Hur',
#    'title': 'First came bank failures. Now comes the House hearing',
#    'description': 'Federal regulators are being called to testify before the House Financial Services Committee on Tuesday about the collapse of Silicon Valley Bank and Signature Bank.',
#    'url': 'https://www.cnn.com/2023/03/26/investing/stocks-week-ahead/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230324164031-svb-headquarters-0313.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-26T11:37:34Z',
#    'content': 'A version of this story first appeared in CNN Business Before the Bell newsletter. Not a subscriber? You can sign up\xa0right here. You can listen to an audio version of the newsletter by clicking the s… [+5692 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Silicon Valley Bank: Money in failed US bank is safe - US government',
#    'description': 'Depositors with Silicon Valley Bank can access all their money from Monday, US officials say.',
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-64935170',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/115F4/production/_128965117_760c6bb963734859bf860851f0e26e22223b4c510_117_5500_30945500x3094.jpg',
#    'publishedAt': '2023-03-12T22:51:40Z',
#    'content': 'People and businesses who have money deposited with failed US bank Sillicon Valley Bank (SVB) will be able to access all their cash from Monday, the US government has said.\r\nA statement from the Trea… [+483 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Morgan Meaker',
#    'title': 'Silicon Valley Bank’s Failure Deals a Blow to Europe’s Startups',
#    'description': 'The US lender filled a niche for European tech companies that no one else could, or would.',
#    'url': 'https://www.wired.com/story/silicon-valley-bank-europe-tech-startup/',
#    'urlToImage': 'https://media.wired.com/photos/640f9dd4412651fa6ee14690/191:100/w_1280,c_limit/Euro_GettyImages-1409427454_biz.jpg',
#    'publishedAt': '2023-03-13T22:05:54Z',
#    'content': "Silicon Valley Bank's struggles started with a bad bet on long-dated US bonds. Rising interest rates meant that the value of those bonds fell. As depositors started to worry about the bank's balance … [+3167 chars]"},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Anna Cooban',
#    'title': "Europe's banking stocks suffer biggest drop in a year",
#    'description': "Investors dumped European bank stocks for a third straight day Monday, despite dramatic moves over the weekend by the US and UK governments to shore up confidence in the financial system following Friday's collapse of Silicon Valley Bank.",
#    'url': 'https://www.cnn.com/2023/03/13/investing/european-banks-svb-collapse/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230310171400-silicon-valley-bank-031023.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-13T16:03:17Z',
#    'content': 'Investors dumped European bank stocks for a third straight dayMonday, despite dramatic moves over the weekend by the US and UK governments to shore up confidence in the financial system following Fri… [+3449 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Alicia Wallace, Nicole Goodkind, Krystal Hur',
#    'title': 'Stocks fall sharply as bank fears consume global markets',
#    'description': "US stocks tumbled as investors fear the banking sector may have yet more problems to overcome. Credit Suisse's shares fell sharply after the Saudi National Bank said it would not invest any more in the troubled Swiss bank.",
#    'url': 'https://www.cnn.com/business/live-news/stock-market-svb-inflation-ppi-031523/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230313081930-svb-bank-collapse-031023.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-15T11:09:14Z',
#    'content': 'Credit Suisses shares were trading down nearly 22% in Zurich on Wednesday, and the cost of buying insurance against the risk of a Credit Suisse default hit a new record high, according to S&amp;P Glo… [+1223 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Matt Egan',
#    'title': 'JPMorgan is advising First Republic on another potential lifeline, sources say',
#    'description': "JPMorgan Chase's investment bank has been hired to advise First Republic as the embattled regional bank tries to ease concerns about its financial condition, people familiar with the matter told CNN.",
#    'url': 'https://www.cnn.com/2023/03/21/investing/jpmorgan-advises-first-republic/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230321092624-05-first-republic-bank-0316.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-21T13:34:23Z',
#    'content': 'JPMorgan Chases investment bank has been hired to advise First Republic as the embattled regional bank tries to ease concerns about its financial condition, people familiar with the matter told CNN.\r… [+1413 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'UK to help tech firms after Silicon Valley Bank collapse',
#    'description': 'Tech firms caught up in bank collapse will have cashflow needs met, the government says.',
#    'url': 'https://www.bbc.co.uk/news/business-64930944',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/D5A6/production/_128949645_whatsubject.jpg',
#    'publishedAt': '2023-03-12T08:56:00Z',
#    'content': 'The government is working on a plan so that UK tech firms caught up in the collapse of Silicon Valley Bank won\'t run out of cash, it has said.\r\nThe Treasury wants to "minimise damage to some of our m… [+2179 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'The Silicon Valley Bank saga in 80 seconds',
#    'description': 'Has the collapse of two US banks sparked another financial crisis?',
#    'url': 'https://www.bbc.co.uk/news/av/world-us-canada-64952039',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/DBF4/production/_128980365_p0f8n0tv.jpg',
#    'publishedAt': '2023-03-14T10:48:46Z',
#    'content': "I can't say anything at the moment, I'm sorry - Lineker. Video, 00:00:26I can't say anything at the moment, I'm sorry - Lineker"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Asia markets fall as global banking fears widen',
#    'description': 'Indexes in Japan, Hong Kong and Australia fall by more than 1% amid heavier losses in bank shares.',
#    'url': 'https://www.bbc.co.uk/news/business-64973321',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/17B56/production/_129001179_b23c01414ea4f05725b2b52f067f1ebfe810f9d4.png',
#    'publishedAt': '2023-03-16T05:10:17Z',
#    'content': 'Stock markets across Asia fell on Thursday as troubles at international banking giant Credit Suisse intensified fears of a wider bank crisis.\r\nMajor indexes in Japan, Hong Kong and Australia fell by … [+3163 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Nicole Goodkind',
#    'title': 'What comes next in the banking crisis? The early 1990s hold clues',
#    'description': "Investors are searching for clarity in the wake of Friday's collapse of Silicon Valley Bank — the biggest failure of a US bank since 2008. And as they attempt to predict what comes next — be it wider financial chaos, more government regulation, a pause in Fed…",
#    'url': 'https://www.cnn.com/2023/03/14/investing/premarket-stocks-trading/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230313190406-silicon-valley-bank-031323.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-14T12:01:09Z',
#    'content': 'A version of this story first appeared in CNN Business Before the Bell newsletter. Not a subscriber? You can sign up\xa0right here. You can listen to an audio version of the newsletter by clicking the s… [+7716 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Ambani, Adani: Should India break up its big conglomerates?',
#    'description': "A former deputy governor of India's central bank says five big firms are hindering competition in the market.",
#    'url': 'https://www.bbc.co.uk/news/world-asia-india-65108865',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/272C/production/_129182001_gettyimages-106624716-594x594.jpg',
#    'publishedAt': '2023-03-30T02:53:59Z',
#    'content': 'India should dismantle its large conglomerates to increase competition and reduce their ability to charge higher prices, former Reserve Bank of India deputy governor Viral Acharya has argued in a new… [+5437 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'One tourist killed and seven wounded in car ramming attack in Tel Aviv',
#    'description': 'It comes after two British-Israeli sisters were killed in a shooting in the occupied West Bank.',
#    'url': 'https://www.bbc.co.uk/news/world-middle-east-65217134',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/11DDC/production/_129308137_8af419ed8f5ca0a71dbe659855434c019680d1b5.jpg',
#    'publishedAt': '2023-04-07T23:42:15Z',
#    'content': "An Italian tourist has been killed and seven other people wounded in a suspected car ramming attack near a beach in Tel Aviv, Israeli medics say.\r\nItaly's foreign minister said Israel had identified … [+2396 chars]"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Manchester United: Premier League club owes almost £1bn, reveal new figures',
#    'description': 'Manchester United owe £969.6m through a combination of gross debt, bank borrowings and outstanding transfer fees with associated payments, according to new figures.',
#    'url': 'https://www.bbc.co.uk/sport/football/65131177',
#    'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/995E/production/_129226293_gettyimages-1477890536.jpg',
#    'publishedAt': '2023-03-30T18:22:16Z',
#    'content': "Manchester United fans have protested against the club's owners, the Glazer Family, who are considering selling up and have invited bids\r\nManchester United owe £969.6m through a combination of gross … [+1744 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Jody Serrano',
#    'title': 'U.S. Government Saves Silicon Valley Bank After Tech Industry Killed It',
#    'description': 'The U.S. government swooped in on Sunday to save the tech industry from a problem of its own making, announcing that it would ensure all depositors in Silicon Valley Bank had full access to their money by Monday.\xa0Read more...',
#    'url': 'https://gizmodo.com/us-government-backs-deposits-silicon-valley-bank-1850218306',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/dd04516d1e1486b568f5fdcbac4710f7.jpg',
#    'publishedAt': '2023-03-13T12:01:06Z',
#    'content': 'The U.S. government swooped in on Sunday to save the tech industry from a problem of its own making, announcing that it would ensure all depositors in Silicon Valley Bank had full access to their mon… [+2490 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'David Goldman',
#    'title': "What's the next Silicon Valley Bank — and how can the US prevent more chaos?",
#    'description': 'Silicon Valley Bank failed in rapid, stunning fashion Friday. This week, the tech and banking sector are growing skittish about the next shoe to drop.',
#    'url': 'https://www.cnn.com/2023/03/12/investing/silicon-valley-bank-bailout/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230312095700-02-silicon-valley-bank-031223.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-12T14:40:57Z',
#    'content': 'Silicon Valley Bank failed in rapid, stunning fashion Friday. This week, the tech and banking sector are growing skittish about the next shoe to drop.\r\nWhat took place Friday was an old-fashioned ban… [+4773 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Faith Karimi',
#    'title': "Irene Gakwa's boyfriend pleads guilty to stealing money from her after she vanished a year ago in Wyoming",
#    'description': "Nathan Hightman pleaded guilty Tuesday to stealing money from girlfriend Irene Gakwa's bank account and maxing out her credit card after she vanished a year ago in Wyoming.",
#    'url': 'https://www.cnn.com/2023/03/29/us/irene-gakwa-boyfriend-guilty-plea-cec/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/220909142816-06a-irene-gakwa-missing.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-29T13:54:56Z',
#    'content': 'The live-in boyfriend of missing woman Irene Gakwa has pleaded guilty to stealing money from her in the weeks after she vanished a year ago in Wyoming. \r\nGakwas family last saw her on a video call on… [+4524 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Michelle Toh, Robert North',
#    'title': "HSBC is buying SVB's UK business for just over $1",
#    'description': 'HSBC has scooped up the UK arm of Silicon Valley Bank for £1 ($1.2), just days after its business in the United States collapsed in stunning fashion.',
#    'url': 'https://www.cnn.com/2023/03/13/investing/svb-uk-business-deal-intl-hnk/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230313071812-hsbc-london-file-2022-restricted.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-13T07:29:36Z',
#    'content': 'HSBC has scooped up the UK arm of Silicon Valley Bank for £1 ($1.2), just days after its business in the United States collapsed in stunning fashion.\r\nSVB UK had been placed into insolvency by the Ba… [+585 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Bank of America said to buy Signature Bank, tweets Bill Ackman - Reuters',
#    'description': 'Bank of America said to buy Signature Bank, tweets Bill Ackman\xa0\xa0Reuters',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMibGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2J1c2luZXNzL2ZpbmFuY2UvYmFuay1hbWVyaWNhLXNhaWQtYnV5LXNpZ25hdHVyZS1iYW5rLXR3ZWV0cy1iaWxsLWFja21hbi0yMDIzLTAzLTE3L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-17T18:08:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': "Australia's central bank says bank stress just one consideration for ... - Reuters.com",
#    'description': "Australia's central bank says bank stress just one consideration for ...\xa0\xa0Reuters.com",
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMid2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL21hcmtldHMvYXVzdHJhbGlhcy1jZW50cmFsLWJhbmstc2F5cy1iYW5rLXN0cmVzcy1qdXN0LW9uZS1jb25zaWRlcmF0aW9uLXJhdGUtcG9saWN5LTIwMjMtMDMtMTkv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-19T23:29:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Bank of Korea says non-bank firms face stress from weak property ... - Reuters',
#    'description': 'Bank of Korea says non-bank firms face stress from weak property ...\xa0\xa0Reuters',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMicGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL21hcmtldHMvYXNpYS9iYW5rLWtvcmVhLXNheXMtbm9uLWJhbmstZmlybXMtZmFjZS1zdHJlc3Mtd2Vhay1wcm9wZXJ0eS1tYXJrZXQtMjAyMy0wMy0yMy_SAQA?oc%3D5%26hl%3Den-CA%26gl%3DCA%26ceid%3DCA:en&gl=FR&hl=en-CA&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-23T02:02:16Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Italian bank loans to firms fall as demand weakens: central bank - Reuters',
#    'description': 'Italian bank loans to firms fall as demand weakens: central bank\xa0\xa0Reuters',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMibGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL21hcmtldHMvZXVyb3BlL2l0YWxpYW4tYmFuay1sb2Fucy1maXJtcy1mYWxsLWRlbWFuZC13ZWFrZW5zLWNlbnRyYWwtYmFuay0yMDIzLTA0LTA3L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-04-07T16:27:00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Stocks rebound as US and UK seek to calm investors',
#    'description': "Markets higher after UK and US again seek to calm investor fears over banks' stability.",
#    'url': 'https://www.bbc.co.uk/news/business-64985356',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/11BB1/production/_129052627_620bc52e-1eda-453f-8727-f6f5cde123d2.jpg',
#    'publishedAt': '2023-03-21T18:59:17Z',
#    'content': "Stock markets around the world have bounced back after the US and UK governments again reassured markets about banks' stability.\r\nInvestors have recently been unnerved by a string of bank failures.\r\n… [+2414 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Andy Greenberg',
#    'title': 'North Korea Is Now Mining Crypto to Launder Its Stolen Loot',
#    'description': 'A spy group working for the Kim regime has been feeding stolen coins into crypto mining services in an effort to throw tracers off their trail.',
#    'url': 'https://www.wired.com/story/north-korea-apt43-crypto-mining-laundering/',
#    'urlToImage': 'https://media.wired.com/photos/64223c901d8bed66b5b38e35/191:100/w_1280,c_limit/North-Korea-Found-a-Clever-New-Way-to-Launder-Stolen-Crypto-Security-GettyImages-1280627476.png',
#    'publishedAt': '2023-03-28T15:00:00Z',
#    'content': "In the cryptocurrency ecosystem, coins have a story, tracked in the unchangeable blockchains underpinning their economy. The only exception, in some sense, is cryptocurrency that's been freshly gener… [+3289 chars]"},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Sara Murray, Annie Grayer, Alayna Treene',
#    'title': 'Comer says Treasury will allow Oversight Committee to review certain bank activity reports related to Biden family and business partners',
#    'description': 'House Oversight Chairman James Comer said in a statement Tuesday the US Treasury Department will allow him to review certain bank activity reports related to members of the Biden family and their business partners.',
#    'url': 'https://www.cnn.com/2023/03/14/politics/comer-biden-family-bank-activity-reports/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230314012505-james-comer-031423.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-14T12:00:15Z',
#    'content': 'House Oversight Chairman James Comer said in a statement Tuesday the US Treasury Department will allow him to review certain bank activity reports related to members of the Biden family and their bus… [+2614 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Anna Cooban',
#    'title': "Credit Suisse's gold bars, hats and bags are cropping up in online stores",
#    'description': "Hats, bags and gold bars emblazoned with Credit Suisse's logo are being sold on resale sites, having popped up mere hours after the 167-year-old bank was saved from collapse by rival UBS.",
#    'url': 'https://www.cnn.com/2023/03/21/business/credit-suisse-merchandise-online/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230321120525-credit-suisse-zurich-031923-restricted.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-21T13:33:43Z',
#    'content': 'Hats, bags and gold bars emblazoned with Credit Suisses logo are being sold on resale sites, having popped up mere hours after the 167-year-old bank was saved from collapse by rival UBS. \r\nThe emerge… [+1609 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Stephen Collinson',
#    'title': "Analysis: America's biggest problem is its politics, not its banks",
#    'description': 'The dramatic meltdown of Silicon Valley Bank is proving one thing for sure -- the biggest systemic risk to the United States lies not in its banking system but in its polarized politics.',
#    'url': 'https://www.cnn.com/2023/03/14/politics/american-banking-politics-svb-analysis/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230314000551-dome-of-capitol-031423.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-14T04:44:58Z',
#    'content': 'The dramatic meltdown of Silicon Valley Bank is proving one thing for sure the biggest systemic risk to the United States lies not in its banking system but in its polarized politics.\r\nSo far, the Bi… [+10119 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Matt Egan',
#    'title': 'The Fed needs to stop raising rates now, former FDIC chair says after Silicon Valley Bank failure',
#    'description': 'Sheila Bair, a top banking regulator during the 2008 financial crisis, says the stunning implosion of Silicon Valley Bank is exactly why the Federal Reserve needs to halt its war on inflation.',
#    'url': 'https://www.cnn.com/2023/03/13/investing/sheila-bair-svb-fed-rates/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230313110934-01-sheila-bair-file-01723.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-13T11:27:26Z',
#    'content': 'Sheila Bair, a top banking regulator during the 2008 financial crisis, says the stunning implosion of Silicon Valley Bank is exactly why the Federal Reserve needs to halt its war on inflation.\r\nThe F… [+2812 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Stephen Collinson',
#    'title': 'Analysis: Biden team scrambles to contain financial and political contagion',
#    'description': "The Biden administration's scramble to prevent financial contagion from the crash of Silicon Valley Bank is both an attempt to shield a resilient but still-vulnerable economy and to prevent grave political fallout.",
#    'url': 'https://www.cnn.com/2023/03/13/politics/biden-silicon-valley-bank-politics/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230307101055-white-house-file.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-13T04:02:23Z',
#    'content': 'The Biden administrations scramble to prevent financial contagion from the crash of Silicon Valley Bank is both an attempt to shield a resilient but still-vulnerable economy and to prevent grave poli… [+10297 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Mark Thompson, Anna Cooban',
#    'title': 'Credit Suisse shares crash as Saudi investor rules out more funds',
#    'description': 'Shares of Credit Suisse crashed more than 20% Wednesday to a new record low after its biggest backer appeared to rule out providing any more funding for the embattled Swiss lender.',
#    'url': 'https://www.cnn.com/2023/03/15/investing/credit-suisse-shares-saudi-national-bank/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230315104324-credit-suisse-file-102622.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-15T11:43:21Z',
#    'content': 'Shares of Credit Suisse crashed more than 20% Wednesday to a new record low after its biggest backer appeared to rule out providing any more funding for the embattled Swiss lender. \r\nIn an interview … [+3598 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mat Smith',
#    'title': 'The Morning After: Netflix wins six Oscars',
#    'description': 'Netflix took home six Oscars last night, besting all the other streaming services, but a single film, Everything, Everywhere All at Once, dominated the biggest awards. It claimed three of four of the acting awards, along with Best Director and Best Picture.Ne…',
#    'url': 'https://www.engadget.com/the-morning-after-netflix-wins-six-oscars-111543725.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/_2DZ2YVThX3EZZ5fKLz59Q--~B/Zmk9ZmlsbDtoPTYzMDtweW9mZj0wO3c9MTIwMDthcHBpZD15dGFjaHlvbg--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-06/d79853b0-af45-11ea-bf29-431281528203.cf.jpg',
#    'publishedAt': '2023-03-13T11:15:43Z',
#    'content': 'Netflix took home six Oscars last night, besting all the other streaming services, but a single film, Everything, Everywhere All at Once, dominated the biggest awards. It claimed three of four of the… [+4125 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Nicole Goodkind',
#    'title': 'What to expect from the Senate hearings on recent bank failures',
#    'description': "Silicon Valley Bank's liquidity crisis and subsequent downfall sent waves of panic through the financial system in early March, setting off a chain reaction of chaos with which regional banks are still grappling.",
#    'url': 'https://www.cnn.com/2023/03/28/investing/senate-banking-hearing-svb/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230327153649-u-s-capitol-building-1208-file-restricted.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-28T10:47:08Z',
#    'content': 'Silicon Valley Banks liquidity crisis and subsequent downfall sent waves of panic through the financial system in early March, setting off a chain reaction of chaos with which regional banks are stil… [+4043 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Washington Desk',
#    'title': 'Biden asks banking regulators to toughen some rules after recent bank failures',
#    'description': 'President Biden on Thursday urged banking regulators to take additional steps to reduce the risk of more mid-sized bank failures like Silicon Valley Bank and Signature Bank.',
#    'url': 'https://www.npr.org/2023/03/30/1167140976/biden-banks-regulators',
#    'urlToImage': 'https://media.npr.org/assets/img/2023/03/30/ap23087701263371_wide-e46cc824f4d2ebcf70831bcad5b05c5ea51c28eb-s1400-c100.jpg',
#    'publishedAt': '2023-03-30T19:28:17Z',
#    'content': 'President Joe Biden on Thursday called on banking regulators to take more steps to reduce the risk of mid-sized bank failures.\r\nCarolyn Kaster/AP\r\nPresident Biden on Thursday urged banking regulators… [+2261 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Mark Thompson',
#    'title': 'The coordinated effort to boost the flow of US dollars through the global financial system aims to keep credit flowing to households and businesses',
#    'description': 'The US Federal Reserve and several other major central banks announced a coordinated effort Sunday night to boost the flow of US dollars through the global financial system with the aim of keeping credit flowing to households and businesses.',
#    'url': 'https://www.cnn.com/2023/03/19/economy/central-banks-fed-dollar-liquidity/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230319172016-federal-reserve-building-file-2022-restricted.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-19T21:54:42Z',
#    'content': 'The US Federal Reserve and several other major central banks announced a coordinated effort Sunday night to boost the flow of US dollars through the global financial system with the aim of keeping cr… [+2622 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mchittum@insider.com (Morgan Chittum)',
#    'title': 'First Citizens Bank jumps 50% after deal to acquire assets of collapsed Silicon Valley Bank',
#    'description': 'Shares of the Raleigh, North Carolina-based bank hit an intraday high of over $880, its highest level in more than a year.',
#    'url': 'https://markets.businessinsider.com/news/stocks/first-citizens-stock-price-silicon-valley-bank-svb-deal-news-2023-3',
#    'urlToImage': 'https://i.insider.com/6421b7d20237f90018531646?width=1200&format=jpeg',
#    'publishedAt': '2023-03-27T16:44:19Z',
#    'content': 'Shares of First Citizens Bank surged as much as 50% on Monday after it was announced that the bank had agreed to buy assets from collapsed Silicon Valley Bank.\xa0\r\nThe Nasdaq-listed shares hit an intra… [+1567 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Maia and Rina Dee: Funerals of sisters killed in occupied West Bank to take place',
#    'description': 'Maia and Rina Dee, who used to live in Britain, were shot on their way to a family holiday.',
#    'url': 'https://www.bbc.co.uk/news/world-middle-east-65224751',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1296D/production/_129314167_565a28f71d8430196020e78f9e89f6cef1ade99c0_0_2475_13921000x562.jpg',
#    'publishedAt': '2023-04-09T13:37:16Z',
#    'content': 'The funeral of two British-Israeli sisters killed in a shooting in the occupied West Bank is due to take place on Sunday.\r\nMaia and Rina Dee, aged 20 and 15, were killed on Friday after their car was… [+3415 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Central banks to boost flow of US dollars amid market unease',
#    'description': 'Six central banks move to keep credit flowing worldwide after two big institutions collapsed.',
#    'url': 'https://www.bbc.co.uk/news/business-65010255',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/128B1/production/_129035957_mediaitem129035953.jpg',
#    'publishedAt': '2023-03-20T00:26:00Z',
#    'content': 'Central banks have moved globally to keep credit flowing after an unsettled period in the US banking sector and the Credit Suisse merger. \r\nSix central banks, including the Bank of England, announced… [+3341 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Matt Egan',
#    'title': "'Absolutely idiotic'. SVB insider says employees are angry with CEO",
#    'description': "The blame game is on for who caused Silicon Valley Bank's collapse, and the tech sector is pointing the finger at SVB CEO Greg Becker for allowing his company to go down in history as the second-biggest US banking failure on record.",
#    'url': 'https://www.cnn.com/2023/03/13/business/svb-employees-angry-at-ceo/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230313130109-01-svb-silicon-valley-bank-0313.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-13T19:45:48Z',
#    'content': 'The blame game is on for who caused Silicon Valley Banks collapse, and the tech sector is pointing the finger at SVB CEO Greg Becker for allowing his company to go down in history as the second-bigge… [+4343 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Ryan Flynn,Samara Abramson)',
#    'title': 'Why Silicon Valley Bank collapsed, and why it matters',
#    'description': 'Silicon Valley Bank collapsed on Friday, resulting in the second-largest bank failure in US history.',
#    'url': 'https://www.businessinsider.com/why-silicon-valley-bank-collapsed-and-why-it-matters-2023-3',
#    'urlToImage': 'https://i.insider.com/6410e6b19aa2e6001956ee53?width=1200&format=jpeg',
#    'publishedAt': '2023-03-14T21:51:44Z',
#    'content': 'Silicon Valley Bank collapsed on Friday, resulting in the second-largest bank failure in US history.'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Phillip Inman',
#    'title': 'Bank of England calls for tougher pension scheme rules after crisis',
#    'description': 'Bank wants to avoid repeat of situation that followed Kwasi Kwarteng’s calamitous mini-budgetThe Bank of England has called for tougher rules governing pension schemes and major lenders outside the banking mainstream as it seeks to restore confidence in the w…',
#    'url': 'https://www.theguardian.com/business/2023/mar/29/bank-of-england-calls-for-tougher-pension-scheme-rules-after-crisis',
#    'urlToImage': 'https://i.guim.co.uk/img/media/1496fcad9b4923cb8ef3a63c53d302a3d336897d/41_17_1967_1181/master/1967.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=6021285c68ca49962cd9f7b5413daf25',
#    'publishedAt': '2023-03-29T11:33:51Z',
#    'content': 'The Bank of England has called for tougher rules governing pension schemes and major lenders outside the banking mainstream as it seeks to restore confidence in the wider financial system.\r\nBritish b… [+3564 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Graeme Wearden',
#    'title': 'Credit Suisse ‘takes decisive action’ by borrowing up to £41bn from central bank – business live',
#    'description': 'Rolling coverage of the latest economic and financial news, as troubled Credit Suisse gets central bank support to stem crisis rocking financial markets<ul><li>Credit Suisse: what is happening at Swiss bank and should we be worried?</li></ul>Credit Suisse sha…',
#    'url': 'https://www.theguardian.com/business/live/2023/mar/16/credit-suisse-borrowing-liquidity-swiss-francs-central-bank-ecb-lagarde-jeremy-hunt-business-live',
#    'urlToImage': 'https://i.guim.co.uk/img/media/21a31d1e587727117a64d74a357167198aeb9ca0/0_180_3000_1800/master/3000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctbGl2ZS5wbmc&enable=upscale&s=d28a3a67c1309cd71f05d1a1e0ecfadf',
#    'publishedAt': '2023-03-16T07:28:49Z',
#    'content': 'Jeremy Hunt welcomes Credit Suisse support, and is following situation closely\r\nChancellor JeremyHunt says he is encouraged by news that Switzerlands central bank had offered liquidity to Credit Suis… [+4282 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': "The Fed could finally pull back its aggressive policy this month - but it'd be doing so for all the wrong reasons, DataTrek says",
#    'description': 'Given the failures of Silicon Valley Bank and Signature bank, as well as cooling CPI, markets are pricing in a policy pivot in March.',
#    'url': 'https://markets.businessinsider.com/news/stocks/fed-rate-hike-pivot-inflation-cpi-silicon-valley-bank-failure-2023-3',
#    'urlToImage': 'https://i.insider.com/641070a06966eb001957c01e?width=1200&format=jpeg',
#    'publishedAt': '2023-03-14T15:01:24Z',
#    'content': 'The Federal Reserve this month could pump the brakes on monetary policy, but central bankers would be doing so for all the wrong reasons, according to DataTrek Research.\r\nAny policy loosening would l… [+2193 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Krystal Hur',
#    'title': 'Dow falls 500 points as banking fears spread',
#    'description': 'The Dow opened the day with a decline of more than 500 points Wednesday as banking fears spread across global markets.',
#    'url': 'https://www.cnn.com/2023/03/15/investing/markets-bank-sector-march-15/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230314090937-01-nyse-0313.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-15T13:36:42Z',
#    'content': 'The Dow opened the day with a decline of more than 500 points Wednesday as banking fears spread across global markets.\r\nThe S&amp;P and Nasdaq slipped roughly 2% and 1.5%, respectively.\r\nShares of em… [+1731 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mturner@businessinsider.com (Matt Turner)',
#    'title': 'Why Silicon Valley Bank failed',
#    'description': "Wondering what happened at Silicon Valley Bank? SVB's recent actions are partly to blame, but the seeds of its demise were planted months ago.",
#    'url': 'https://www.businessinsider.com/silicon-valley-bank-failure-what-happened-bank-run-explained-2023-3',
#    'urlToImage': 'https://i.insider.com/640e334d340fa00018fda164?width=1200&format=jpeg',
#    'publishedAt': '2023-03-12T20:42:49Z',
#    'content': 'Wondering what the hell just happened at Silicon Valley Bank?\r\nThe California bank was closed by regulators on Friday and put under the control of the Federal Deposit Insurance Corporation (FDIC). Th… [+5186 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 
00Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}]}

# %% [markdown]
# # Transform
# Transform into dataframes to load as csv's

# %% [markdown]
# ### Function to Transform

# %%
# Function needs to grab just the articles, cut unneeded fields, renamed date
def transform_snapshot(snapshot):
    # Create a df from just the articles in the snapshot
    df = pd.DataFrame(snapshot["articles"])

    # Cut out unneeded fields
    df_cut = df.loc[:,['publishedAt', 'title', 'description']]

    # rename "publishedAt" to be "date"
    df_cut.rename(columns={"publishedAt": "date"}, inplace = True)

    # Add column where title and description are combined to increase word count for vader to work with
    df_cut['summary'] = df_cut['title'] + df_cut['description']

    # Drop the redundant columns of title and description
    df_cut.drop(columns=['title','description'], inplace=True)

    # Clean up the date column to just have the day
    # cast the date column to datetime
    # grab just the date of the timestamp
    df_cut = df_cut.astype({"date": "datetime64"})
    df_cut['date'] = df_cut['date'].apply( lambda x: x.date())

    return df_cut

# %% [markdown]
# ### Transform BTC

# %%
# apply the transform function
btc_snapshot_df = transform_snapshot(BTC_snapshot)
btc_snapshot_df
# Out:
#           date                                            summary
# 0   2023-04-13  Twitter Partners with eToro to Let Users Buy a...
# 1   2023-04-06  Here’s How to Find the Original Bitcoin Manife...
# 2   2023-04-04  Cryptoverse: Bitcoin traders like their option...
# 3   2023-03-20  In which Balaji gives away at least a million ...
# 4   2023-04-05  Michael Saylor's MicroStrategy adds to its bit...
# ..         ...                                                ...
# 95  2023-04-05  Bitcoin: MicroStrategy Buys 1045 BTC for $29.3...
# 96  2023-04-10  Cathie Wood Backs Balaji’s $1M BTC Forecast, D...
# 97  2023-03-17  Why Bitcoin Miner Stocks Soared This WeekBitco...
# 98  2023-03-17  Over $55M Crypto Shorts Blown Away In 12 Hours...
# 99  2023-03-17  Analyst Warns: Bitcoin Price Surge Above $26,0...
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Doge News

# %%
# Apply the transform function
doge_snapshot_df = transform_snapshot(doge_snapshot)
doge_snapshot_df
# Out:
#           date                                            summary
# 0   2023-04-06  You Can Remove That Stupid Doge Icon From Your...
# 1   2023-04-03  Dogecoin Jumps After Token's Symbol Replaces B...
# 2   2023-04-06  Dogecoin's sharp rally fades after brief burst...
# 3   2023-04-04  Dogecoin Soars 30% After Elon Musk Replaces Tw...
# 4   2023-04-05  Breakingviews - Elon Musk's Doge barks up SEC'...
# ..         ...                                                ...
# 95  2023-04-12  Ethereum Trades Flat After Ethereum Shanghai U...
# 96  2023-04-01  Elon Musk requests dismissal of $258B Dogecoin...
# 97  2023-04-07  Dogecoin Tanks After Twitter Restores Iconic L...
# 98  2023-04-04  Twitter is no longer the bird app, changes ico...
# 99  2023-04-04  Dogecoin's Value Skyrockets After Elon Musk Ch...
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Banking News

# %%
# Apply the transform function
banking_snapshot_df = transform_snapshot(bank_snapshot)
banking_snapshot_df

# %% [markdown]
# # Load

# %%
# Write btc to csv
btc_snapshot_df.to_csv("Resources_crypto_articles/btc_snapshot_after_SVB.csv")

# %%
# Write banking df to csv
banking_snapshot_df.to_csv("News_Snapshots/banking_snapshot_410.csv")

# %%
# Write crypto df to csv
crypto_snapshot_df.to_csv("News_Snapshots/crypto_snapshot_410.csv")

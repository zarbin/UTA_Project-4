# %% [markdown]
# # Import dependencies

# %%
# Dataset used: https://www.kaggle.com/datasets/gpreda/elon-musk-tweets

# %%
import pandas as pd

# %% [markdown]
# ### NTLK

# %%
import nltk

# Download the lexicon
nltk.download("vader_lexicon")

# Import the lexicon 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# SentimentIntensityAnalyzer.polarity_score()function provides the polarity of the text rendering the dictionary format
# of 4 keys neg, neu, pos and compound
# neg, neu, and pos should add to 1
# Compound is overall and is between -1 and 1
# Create an instance of SentimentIntensityAnalyzer
sent_analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jennifershulyak/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Example! 
sentence = "VADER is pretty good at identifying the underlying sentiment of a text!"
print(sent_analyzer.polarity_scores(sentence))
# Out:
# {'neg': 0.0, 'neu': 0.585, 'pos': 0.415, 'compound': 0.75}

# %% [markdown]
# ### Import Musk File and Explore!

# %%
# Read in and look at twitter data
pd.set_option('display.max_colwidth', 100)
df = pd.read_csv("elon_musk_tweets.csv")
df.head()
# Out:
#                     id  user_name user_location           user_description  \
# 0  1544379368478212100  Elon Musk           NaN  Mars & Cars, Chips & Dips
# 1  1544377493263720450  Elon Musk           NaN  Mars & Cars, Chips & Dips
# 2  1544377130590552064  Elon Musk           NaN  Mars & Cars, Chips & Dips
# 3  1544375575724400645  Elon Musk           NaN  Mars & Cars, Chips & Dips
# 4  1544375148605853699  Elon Musk           NaN  Mars & Cars, Chips & Dips
#
#                 user_created  user_followers  user_friends  user_favourites  \
# 0  2009-06-02 20:12:29+00:00       101240855           115            13503
# 1  2009-06-02 20:12:29+00:00       101240806           115            13503
# 2  2009-06-02 20:12:29+00:00       101240806           115            13503
# 3  2009-06-02 20:12:29+00:00       101240806           115            13503
# 4  2009-06-02 20:12:29+00:00       101240806           115            13503
#
#    user_verified                       date  \
# 0           True  2022-07-05 17:55:09+00:00
# 1           True  2022-07-05 17:47:42+00:00
# 2           True  2022-07-05 17:46:15+00:00
# 3           True  2022-07-05 17:40:05+00:00
# 4           True  2022-07-05 17:38:23+00:00
#
#                                                                                                   text  \
# 0  @BillyM2k I find the gold toe sock – inevitably off kilter &amp; washed out – a little troubling...
# 1                                                                   Sock Con, the conference for socks
# 2            Always something new for the magazine cover and the articles practically write themselves
# 3                                                                     @ExplainThisBob This guy gets it
# 4              Sock tech is so advanced that you can get pretty much anything in sock form these days!
#
#   hashtags              source  retweets  favorites  is_retweet
# 0      NaN  Twitter for iPhone       335       6542       False
# 1      NaN  Twitter for iPhone      1451      30753       False
# 2      NaN  Twitter for iPhone      1284      28610       False
# 3      NaN  Twitter for iPhone       131       3640       False
# 4      NaN  Twitter for iPhone      1191      23790       False

# %%
# cut df to just be the "date" and "text" columns
df_justtweets = df.loc[:, ["date", "text"]]
print("The number of tweets in this dataset: {}".format(len(df_justtweets)))
df_justtweets.head()
# Out:
# The number of tweets in this dataset: 4154
#                         date  \
# 0  2022-07-05 17:55:09+00:00
# 1  2022-07-05 17:47:42+00:00
# 2  2022-07-05 17:46:15+00:00
# 3  2022-07-05 17:40:05+00:00
# 4  2022-07-05 17:38:23+00:00
#
#                                                                                                   text
# 0  @BillyM2k I find the gold toe sock – inevitably off kilter &amp; washed out – a little troubling...
# 1                                                                   Sock Con, the conference for socks
# 2            Always something new for the magazine cover and the articles practically write themselves
# 3                                                                     @ExplainThisBob This guy gets it
# 4              Sock tech is so advanced that you can get pretty much anything in sock form these days!

# %% [markdown]
# # Identify Tweets with Crypto buzzwords

# %%
# Buzzwords 
buzzwords = ["bitcoin", "doge", "crypto"]
def check_for_crypto(tweet):
    return tweet

# %% [markdown]
# # Vader

# %%
# Function to gives a polarity rather than numerical output
def format_output(output_dict):
  
  polarity = "neutral"

  if(output_dict['compound']>= 0.05):
    polarity = "positive"

  elif(output_dict['compound']<= -0.05):
    polarity = "negative"

  return polarity

# %%
# Function to apply each row of the df to the sent_analyzer
def predict_sentiment(text):
  
  output_dict =  sent_analyzer.polarity_scores(text)
  return format_output(output_dict)

# %%
# Run the predictions
df_justtweets["vader_prediction"] = df_justtweets["text"].apply(predict_sentiment)
df_justtweets
# Out:
#                            date  \
# 0     2022-07-05 17:55:09+00:00
# 1     2022-07-05 17:47:42+00:00
# 2     2022-07-05 17:46:15+00:00
# 3     2022-07-05 17:40:05+00:00
# 4     2022-07-05 17:38:23+00:00
# ...                         ...
# 4149  2023-03-27 10:28:54+00:00
# 4150  2023-03-27 10:24:39+00:00
# 4151  2023-03-27 10:23:57+00:00
# 4152  2023-03-27 10:17:47+00:00
# 4153  2023-03-27 09:12:41+00:00
#
#                                                                                                      text  \
# 0     @BillyM2k I find the gold toe sock – inevitably off kilter &amp; washed out – a little troubling...
# 1                                                                      Sock Con, the conference for socks
# 2               Always something new for the magazine cover and the articles practically write themselves
# 3                                                                        @ExplainThisBob This guy gets it
# 4                 Sock tech is so advanced that you can get pretty much anything in sock form these days!
# ...                                                                                                   ...
# 4149               @CatherinScience That we extend consciousness to the stars and understand the Universe
# 4150                                                                         @cb_doge Twitter is the news
# 4151                       @Rainmaker1973 That’s what people who have the woke mind virus look like to me
# 4152                                              @Rainmaker1973 Reminds me of The Marker from Dead Space
# 4153                                                                                   @cb_doge Seriously
#
#      vader_prediction
# 0            negative
# 1             neutral
# 2             neutral
# 3             neutral
# 4            positive
# ...               ...
# 4149         positive
# 4150          neutral
# 4151         positive
# 4152         negative
# 4153         negative
#
# [4154 rows x 3 columns]

# %% [markdown]
# # Keep just the crypto tweets

# %%
# Take just the tweets about cryt
df_justtweets[df_justtweets["text"].str.contains('doge|Doge|crypto|Crypto|bitcoin|Bitcoin')]
# Out:
#                            date  \
# 9     2022-07-06 18:02:11+00:00
# 23    2022-07-07 20:58:09+00:00
# 56    2022-07-12 05:49:03+00:00
# 75    2022-07-13 06:17:07+00:00
# 105   2022-07-15 21:15:56+00:00
# ...                         ...
# 4112  2023-03-28 02:53:27+00:00
# 4139  2023-03-27 17:33:12+00:00
# 4140  2023-03-27 17:32:54+00:00
# 4150  2023-03-27 10:24:39+00:00
# 4153  2023-03-27 09:12:41+00:00
#
#                                                                                                      text  \
# 9                                             @mishaboar @boringcompany Supporting Doge wherever possible
# 23    @cb_doge Not bad! \n\nIt is high time that the future looked like the future.\n\nSame goes for f...
# 56                                                                   @cb_doge But Fifth Element was great
# 75                                                                                 @cb_doge Ancient times
# 105                                                             @teslaownersSV @cb_doge It’s a flat trade
# ...                                                                                                   ...
# 4112                                                               @cb_doge Trying my best for the humans
# 4139                                                                               @cb_doge That was wild
# 4140                                    @HumbleBitcoiner US foreign policy now dropping below bronze tier
# 4150                                                                         @cb_doge Twitter is the news
# 4153                                                                                   @cb_doge Seriously
#
#      vader_prediction
# 9            positive
# 23           positive
# 56           positive
# 75            neutral
# 105           neutral
# ...               ...
# 4112         positive
# 4139          neutral
# 4140          neutral
# 4150          neutral
# 4153         negative
#
# [130 rows x 3 columns]

# %%
df_just_crypto_tweet = df_justtweets.loc[:, ["date", "vader_prediction"]]
df_just_crypto_tweet
# Out:
#                            date vader_prediction
# 0     2022-07-05 17:55:09+00:00         negative
# 1     2022-07-05 17:47:42+00:00          neutral
# 2     2022-07-05 17:46:15+00:00          neutral
# 3     2022-07-05 17:40:05+00:00          neutral
# 4     2022-07-05 17:38:23+00:00         positive
# ...                         ...              ...
# 4149  2023-03-27 10:28:54+00:00         positive
# 4150  2023-03-27 10:24:39+00:00          neutral
# 4151  2023-03-27 10:23:57+00:00         positive
# 4152  2023-03-27 10:17:47+00:00         negative
# 4153  2023-03-27 09:12:41+00:00         negative
#
# [4154 rows x 2 columns]

# %%
df_just_crypto_tweet.to_csv("../Sentiments/EMusk_tweets.csv")
